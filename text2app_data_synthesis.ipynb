# %% [markdown]
# <a href="https://colab.research.google.com/github/Masum06/Text2App/blob/master/text2app_data_synthesis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install PyDictionary
# Out:
# Collecting PyDictionary
#   Downloading https://files.pythonhosted.org/packages/d5/0b/575893d32fd0484f3d05a0d754fd35226fee7257b433576484cd7455e429/PyDictionary-2.0.1-py3-none-any.whl
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from PyDictionary) (7.1.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from PyDictionary) (2.23.0)
# Requirement already satisfied: bs4 in /usr/local/lib/python3.7/dist-packages (from PyDictionary) (0.0.1)
# Collecting goslate
#   Downloading https://files.pythonhosted.org/packages/39/0b/50af938a1c3d4f4c595b6a22d37af11ebe666246b05a1a97573e8c8944e5/goslate-1.5.1.tar.gz
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->PyDictionary) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->PyDictionary) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->PyDictionary) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->PyDictionary) (2020.12.5)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.7/dist-packages (from bs4->PyDictionary) (4.6.3)
# Collecting futures
#   Downloading https://files.pythonhosted.org/packages/05/80/f41cca0ea1ff69bce7e7a7d76182b47bb4e1a494380a532af3e8ee70b9ec/futures-3.1.1-py3-none-any.whl
# Building wheels for collected packages: goslate
#   Building wheel for goslate (setup.py) ... done
#   Created wheel for goslate: filename=goslate-1.5.1-cp37-none-any.whl size=11376 sha256=609c14a957a0d2e7b75d3d6b301e9930b4ddcf8dd1562c2e34261633d2e8a30b
#   Stored in directory: /root/.cache/pip/wheels/4f/7f/28/6f52271012a7649b54b1a7adaae329b4246bbbf9d1e4f6e51a
# Successfully built goslate
# Installing collected packages: futures, goslate, PyDictionary
# Successfully installed PyDictionary-2.0.1 futures-3.1.1 goslate-1.5.1

# %% [markdown]
# # Helper functions

# %%
import random
import string
from PyDictionary import PyDictionary
from datetime import datetime

random.seed(datetime.now())
dictionary=PyDictionary()

all_vis_components = ['button', 'switch', 'accelerometer', 'ball', 'text2speech', 'player', 'video_player', 'textbox', 'passwordtextbox', 'timepicker', 'datepicker']
colors = ["red", "green", "black", "cyan", "pink", "magenta", "blue", "light_gray", "orange", "yellow", "dark_gray", "gray"]

print(all_vis_components)
# Out:
# ['button', 'switch', 'accelerometer', 'ball', 'text2speech', 'player', 'video_player', 'textbox', 'passwordtextbox', 'timepicker', 'datepicker']

# %%
string_num = -1
int_num = -1
float_num = -1

def getStr():
  global string_num 
  string_num += 1
  return "string"+str(string_num)

def getNum():
  global int_num 
  int_num += 1
  return "number"+str(int_num)

def getColor():
  global colors
  return random.choice(colors)

def getSyn(word):
  syns = dictionary.synonym(word)
  if syns:
    return random.choice([word] + syns)
  else:
    return word

def getArticle(word):
  if word[0] in 'aeiou':
    return "an"
  else:
    return "a"

# %% [markdown]
# # Constants

# %%
ValueComponents = {
    "textbox": {"nl": ["the textbox text", "the text in the textbox", "the text in the box", "the textbox content", "the text"], "sar": "textboxtext"},
    "passwordtextbox": {"nl": [""], "sar": "passwordboxtext"},
    "timepicker": {"nl": ["the time", "time", "what time it is", "what is the time"], "sar": "time"}, 
    # "datepicker": {"nl": ["the date and time", "date and time", "date", "the date", "what is the date"], "sar": "date"}
    }

# %%
events = {
    "button": {"clicked": ["clicked", "pressed", "touched"]},
    "switch": {"flipped": ["fliped", "clicked", "pressed", "touched"]},
    "accelerometer": {"shaken": ["shaken", "vibrated"]},
    "ball": {"flung": ["flung", "thrown", "hit"], "reach_edge": ["reaches edge", "touches edge", "cornered"]}
}

# %%
actions = {
    "player": {
        "start": ["play the music", "play the sound", "play", "start the player", "start the music", "initiate player"], 
        "stop": ["stop the music", "stop sound", "stop the sound", "stop"]
        },
    "video_player": {
        "start": ["play the video", "play the clip", "play", "start the video player", "start the video", "initiate video"], 
        "stop": ["stop the video", "stop video", "stop the clip", "stop"]
        },
    "text2speech": ["speak"],
    "ball": ["radius", "speed", "header", "motion", "bounce"]
}

# %%
arguments = ["textbox", "passwordtext", 'time'] #date

# %%
numbers = [["", "first", "1st", "earlier", "initial"] , ["second", "2nd", "next", "later", "following", "the other", "the later"], 
           ["third", "3rd"], ["fourth", "4th"]]

# %%
vis_components = ['textbox', 'button', 'text2speech', 'ball', 'accelerometer', 'video_player', 'switch', 'player', 'label', 'timepicker', 'passwordtextbox'] #, 'datepicker', 
non_repeat_vis_components = ['accelerometer', 'ball', 'text2speech']
repeat_vis_components = list(set(vis_components) - set(non_repeat_vis_components))
components_with_text = ['button', 'switch', 'label'] 
comp_with_src = ['video_player', 'player']
invisible_components = ['text2speech', 'accelerometer', 'ball']
end_with_es = ['text2speech', 'textbox']
canvas_components = ['ball']

event_components = ["button", "switch", "accelerometer", "ball"]
action_components = ["player", "video_player", "text2speech", "ball", "label"]
value_components = ["textbox", "timepicker"] # "passwordtextbox", "datepicker",
rand_source = {"video_player": ["video", "clip"], "player": ["audio", "music", "sound"]}

component_alias = {"textbox": ["textbox", "text box"], "button": ["button"], "ball": ["ball", "circle"], 
                   "text2speech": ["text2speech", "text to speech", "speech"], "accelerometer": ["accelerometer"], 
                  #  "datepicker": ["datepicker", "date picker"], 
                   "timepicker": ["timepicker", "time picker", "time selector"], 
                   "switch": ["switch"], "player": ["music player", "player", "audio player", "music", "audio"], 
                   "video_player": ["video player", "video"], "label": ["label"],
                   "passwordtextbox": ["password box", "pasword text box", "password field"]
                   }

MAX_NUMBER_OF_COMPONENT = 7
SAME_COMPONENT_LIMIT = 3

# %% [markdown]
# # Classes

# %%
class EventComponent:
  component = ""
  event = ""
  nl = []
  number = 0
  event_comp_count = 1

  def __init__(self, component="", number=1, event_comp_count=1):
    self.component = component
    self.event = random.choice(list(events[self.component].keys())) # random.choice(events[self.component]["event"]) 
    self.number = number
    self.event_comp_count = event_comp_count

  def getNL(self):
    if self.component in non_repeat_vis_components or self.event_comp_count==1:
      num = ""
    else:
      num = random.choice(numbers[self.number-1])+" "
    
    event_choice = random.choice(list(events[self.component].keys()))
    comp_nl = random.choice(events[self.component][event_choice])
    new_nl = random.choice(["when", "if"])+" the "+ num + random.choice(component_alias[self.component]) +" is "+ comp_nl + ", "
    return new_nl

# %%
class ActionComponent:
  component = ""
  number = 0
  action_comp_count = 1
  # arguments = []
  val_comps = []
  arg = ""
  nl = ""

  def __init__(self, component, number=1, val_comps=[], action_comp_count=1):
    self.component = component
    self.number = number
    self.actions = actions
    self.val_comps = val_comps
    self.arg = self.getArg()
    self.action_comp_count = action_comp_count

  def getNL(self):
    # new_nl = random.choice(["set", "make"]) + " " + random.choice(self.actions) + " "
    return self.nl

  def getPlayerArg(self):
    arg = random.choice(["start", "stop"])
    nl_arg = arg
    alter = random.choice([0,1])
    if alter:
      if arg == "start":
        nl_arg = "play"
      else:
        nl_arg = "pause"

    self.nl = nl_arg + random.choice([" the <num> player", " the music <num> player", " the music", " music", " player", " audio"])
    if self.action_comp_count > 1:
      self.nl = self.nl.replace("<num>", random.choice(numbers[self.number-1]))
    else:
      self.nl = self.nl.replace("<num> ", "")
    return "<"+arg+">"
  
  def getVideoPlayerArg(self):
    arg = random.choice(["start", "stop"])
    nl_arg = arg
    alter = random.choice([0,1])
    if alter:
      if arg == "start":
        nl_arg = "play"
      else:
        nl_arg = "pause"

    self.nl = nl_arg + random.choice([" the <num> video player", " the <num> video", " the <num> clip", " <num> video", \
                                      " <num> video player", " video", " video player"])
    if self.action_comp_count > 1:
      self.nl = self.nl.replace("<num>", random.choice(numbers[self.number-1]))
    else:
      self.nl = self.nl.replace("<num> ", "")
    return "<"+arg+">"

  def getT2SArg(self):
    use_val_comp = random.choice([0,1,1,1]) # 75% chance of choosing value component
    if len(self.val_comps)>0 and use_val_comp:
      val_name = random.choice(self.val_comps)
      self.val_comps.remove(val_name)
      val = val_name[:-1] # Number of value component cannot be more than 9 (a single digit)
      self.nl = random.choice(["say ", "speak ", "tell ", "speak out "]) + random.choice(ValueComponents[val]["nl"])
      return "<"+ValueComponents[val]['sar']+val_name[-1]+">"
    else:
      val = getStr()
      self.nl = random.choice(["say ", "speak ", "tell ",  "speak out "]) + val
      return val

  def getLabelArg(self):
    use_val_comp = random.choice([0,1,1,1]) # 75% chance of choosing value component
    
    self.nl = random.choice(["set <num> label text to ", "set the <num> label text to ", "set <num> label to ", "set <num> label "])
    if self.action_comp_count > 1:
      self.nl = self.nl.replace("<num>", random.choice(numbers[self.number-1]))
    else:
      self.nl = self.nl.replace(" <num>", "")

    if len(self.val_comps)>0 and use_val_comp:
      val_name = random.choice(self.val_comps)
      self.val_comps.remove(val_name)
      val = val_name[:-1] # Number of value component cannot be more than 9 (a single digit)
      self.nl += random.choice(ValueComponents[val]["nl"])
      val = "<"+ValueComponents[val]['sar']+val_name[-1]+">"
    else:
      val = getStr()
      self.nl += val

    return val
  
  def getBallArg(self):
    arg = random.choice(['radius', 'color', 'speed', 'heading', 'bounce', 'motion'])
    if arg in ['speed', 'radius']:
      val = getNum() #random.choice(['increase', 'decrease'])
      self.nl = "set the " + arg + " to " + val
      return "<"+arg+"> "+val+" </"+arg+">"
    elif arg == 'bounce':
      self.nl = "bounce the ball" 
      return "<bounce>"
    elif arg == 'color':
      val = random.choice(colors)
      self.nl = "set ball color to "+ val.replace("_", " ")
      return "<"+arg+"> <"+val+"> </"+arg+">"
    elif arg == 'motion':
      self.nl = random.choice(["set ball in motion ", "move the ball ", "swing the ball "])
      return "<motion>"
    elif arg == 'heading':
      val = getNum()
      self.nl = "set ball header to "+ val
      return "<"+arg+"> "+val+" </"+arg+">"
    
    

  def getArg(self):
    if self.component == "player":
      return self.getPlayerArg()
    elif self.component == "video_player":
      return self.getVideoPlayerArg()
    elif self.component == "text2speech":
      return self.getT2SArg()
    elif self.component == "ball":
      return self.getBallArg()
    elif self.component == "label":
      return self.getLabelArg()
    else:
      return ""
  
  def getNLArg(self):
    arg = self.arg
    return (self.nl, arg)

# %% [markdown]
# # NL_SAR generation code

# %%
def generate_nl_sar():
  # global vis_components, non_repeat_vis_components, repeat_vis_components
  global string_num, int_num
  string_num = -1
  int_num = -1

  total_vis_components = random.randint(1, MAX_NUMBER_OF_COMPONENT) # limited to fit in screen # CX: 11C7
  selected_components = random.sample(vis_components*SAME_COMPONENT_LIMIT, total_vis_components) # 

  NL = random.choice(["create <app> ", "make <app> ", "<app> ", "<app> ", "give me <app> "])
  app = random.choice(["app", "mobile app", "application", "mobile application", "software"])
  initial = random.choice([getArticle(app)+" ", ""])
  NL = NL.replace("<app>", initial+app)
  NL += random.choice(["with ", "that has ", "consisting ", "containing ", "having ", "consisting of "])
  SAR = ["<complist> "] #Change to <comp>

  comps_count = {}
  # comps_used_count = {}
  event_comp_used_count = {}
  action_comp_used_count = {}
  vis_comp_used_count = {}
  for comp in vis_components:
    comps_count[comp] = 0
    # comps_used_count[comp] = 0
    vis_comp_used_count[comp] = 0
    action_comp_used_count[comp] = 0
    event_comp_used_count[comp] = 0

  event_comps = []
  action_comps = []
  value_comps = []

  # total_vis_components = random.randint(1, MAX_NUMBER_OF_COMPONENT) # limited to fit in screen # CX: 12C5
  # selected_components = random.sample(vis_components*SAME_COMPONENT_LIMIT, total_vis_components)

  for component in selected_components:
    if component in non_repeat_vis_components and comps_count[component]:
      selected_components.remove(component)
      total_vis_components-=1
    else:
      comps_count[component] += 1
      if component in event_components:
        event_comps.append(component)
      if component in action_components:  # Same component can be both event and action, such as "ball"
        action_comps.append(component)
      if component in value_components:
        # if comps_count[component] > 1:
        value_comps.append(component+str(comps_count[component]))
  
  unique_components = list(set(selected_components))

  for i in range(len(selected_components)):
    vis_comp = selected_components[i]
    vis_comp_number =  comps_count[vis_comp]
    vis_comp_nl = random.choice(component_alias[vis_comp])
    article = getArticle(vis_comp_nl)

    vis_comp_used_count[vis_comp] += 1


    # for j in range(vis_comp_number):
      ## Generate NL
    mid_text = ""
    
    if i == total_vis_components - 1 and len(selected_components) > 1: # j == vis_comp_number - 1 and 
      NL += "and "

    give_text = random.choice([0,0,0,1]) # MH: 25% chance of giving a text

    if vis_comp in comp_with_src:
      if give_text: # with 25% possibility set the source to a random video or music
        mid_text = "random_"+ vis_comp + "_source"
        NL += article + " " + vis_comp_nl + " with a random " + random.choice(rand_source[vis_comp])
      else:
        mid_text = getStr()
        NL += article + " " + vis_comp_nl + " with source " + mid_text
    elif vis_comp in components_with_text:
      if give_text:
        mid_text = getStr()
        NL += article + " "+ vis_comp_nl + random.choice([" named ", " with text ", " called "]) + mid_text
      else:
        mid_text = vis_comp + str(vis_comp_used_count[vis_comp]) # MH: DEFAULT TEXT ARGUMENT
        NL += article + " " + vis_comp_nl 
    else:
      NL += article + " " + vis_comp_nl 


    if i == total_vis_components - 1: # j == vis_comp_number - 1 
      NL += " . "
    else:
      NL += " , "

    ## Generate SAR
    if vis_comp in components_with_text+comp_with_src:
      sar_begin_token = "<token> "
      sar_end_token = "</token> "
      SAR.append(sar_begin_token.replace("token", vis_comp))
      SAR.append(mid_text + " ")
      SAR.append(sar_end_token.replace("token", vis_comp))
    else:
      SAR.append("<"+vis_comp+"> ")


  ## Handling plural form
  # if vis_comp_number > 1:
  #   if vis_comp in end_with_es: #add component to this list if it end in es
  #     NL = NL.replace(vis_comp, (vis_comp + "es"))
  #   else: 
  #     NL = NL.replace(vis_comp, vis_comp + "s")

  #Generate SAR for canvas
  # for number in range(vis_comp_number):
  # if vis_comp in canvas_components:
  #   if "<canvas> " in SAR:
  #     idx = SAR.index("</canvas> ") - 1
  #     SAR.insert(idx , "<ball> ")
  #   else:
  #     SAR.append("<canvas> ")
  #     SAR.append("<ball> ")
  #     SAR.append("</canvas> ")
  # else:
  #   sar_token = "<token> "
  #   SAR.append(sar_token.replace("token", vis_comp))

  SAR.append("</complist>") #Change to </comp>
  SAR_str = ""
  for token in SAR:
    SAR_str += token

  sar = SAR_str


  ## SAR for code components
  # print(selected_components)
  # print(event_comps)
  # print(action_comps)
  # print(value_comps)

  if len(action_comps)>0 and len(event_comps)>0:
    sar += " <code> "
    for event_comp in event_comps:
      if action_comps:
        event_comp_used_count[event_comp] += 1
        event_comp_num = event_comp_used_count[event_comp]
        event_comp_count = comps_count[event_comp]
        event_object = EventComponent(event_comp, event_comp_num, event_comp_count)
        NL += event_object.getNL()
        # event = event_object.event #random.choice(events[event_comp])
        sar += "<"+ event_comp + str(event_comp_num) + event_object.event + "> "

        action_comp_name = random.choice(action_comps)
        action_comp_used_count[action_comp_name] += 1
        action_comp_num = action_comp_used_count[action_comp_name]
        action_comps.remove(action_comp_name)
        action_comp_count = comps_count[action_comp_name]

        # Decide whether to use value comp, or which one to use
        # Send or not send that value comp
        # Remove from the value comp list
        action_object = ActionComponent(action_comp_name, action_comp_num, value_comps, action_comp_count)
        value_comps = action_object.val_comps

        (nl, arg) = action_object.getNLArg()
        sar += "<"+action_comp_name + str(action_comp_num) + "> " + arg + " </"+action_comp_name + str(action_comp_num) + "> "
        sar += "</"+ event_comp + str(event_comp_num) + event_object.event + "> "
        NL += nl + " . "

    sar += "</code>"

  NL = ' '.join(NL.split())
  sar = ' '.join(sar.split())
  return NL, sar

# %%
NL, sar = generate_nl_sar()
print(NL)

print(sar)
# Out:
# mobile application containing a video with a random video , a time picker , and a switch with text string0 . if the switch is fliped, pause video .
# <start_comp> <video_player> random_video_player_source </video_player> <timepicker> <switch> string0 </switch> <end_comp> <code> <switch1flipped> <video_player1> <stop> </video_player1> </switch1flipped> </code>

# %% [markdown]
# # Generating dataset

# %%
nl_list = []
nl_mod_list = []
sar_list = []

for i in range(55000):
  nl, sar = generate_nl_sar()
  if "<player>" in sar:
    print(sar)
  nl_list.append(nl)
  sar_list.append(sar)
# Out:
# Streaming output truncated to the last 5000 lines.
# <start_comp> <player> random_player_source </player> <player> random_player_source </player> <label> label1 </label> <accelerometer> <textbox> <passwordtextbox> <video_player> string0 </video_player> <end_comp> <code> <accelerometer1shaken> <video_player1> <stop> </video_player1> </accelerometer1shaken> </code>
# <start_comp> <text2speech> <video_player> string0 </video_player> <video_player> string1 </video_player> <switch> switch1 </switch> <label> string2 </label> <player> random_player_source </player> <timepicker> <end_comp> <code> <switch1flipped> <video_player1> <start> </video_player1> </switch1flipped> </code>
# <start_comp> <player> random_player_source </player> <ball> <passwordtextbox> <textbox> <end_comp> <code> <ball1flung> <player1> <start> </player1> </ball1flung> </code>
# <start_comp> <textbox> <player> string0 </player> <end_comp>
# <start_comp> <switch> switch1 </switch> <timepicker> <label> label1 </label> <ball> <player> string0 </player> <textbox> <timepicker> <end_comp> <code> <switch1flipped> <label1> <time1> </label1> </switch1flipped> <ball1reach_edge> <ball1> <color> <cyan> </color> </ball1> </ball1reach_edge> </code>
# <start_comp> <player> random_player_source </player> <player> string0 </player> <passwordtextbox> <switch> string1 </switch> <label> label1 </label> <accelerometer> <label> label2 </label> <end_comp> <code> <switch1flipped> <player1> <stop> </player1> </switch1flipped> <accelerometer1shaken> <label1> string2 </label1> </accelerometer1shaken> </code>
# <start_comp> <label> label1 </label> <textbox> <player> string0 </player> <timepicker> <end_comp>
# <start_comp> <timepicker> <accelerometer> <player> string0 </player> <passwordtextbox> <switch> switch1 </switch> <ball> <end_comp> <code> <accelerometer1shaken> <ball1> <motion> </ball1> </accelerometer1shaken> </code>
# <start_comp> <video_player> string0 </video_player> <button> button1 </button> <textbox> <accelerometer> <player> string1 </player> <text2speech> <end_comp> <code> <button1clicked> <text2speech1> string2 </text2speech1> </button1clicked> <accelerometer1shaken> <video_player1> <stop> </video_player1> </accelerometer1shaken> </code>
# <start_comp> <player> string0 </player> <switch> switch1 </switch> <end_comp> <code> <switch1flipped> <player1> <stop> </player1> </switch1flipped> </code>
# <start_comp> <text2speech> <player> string0 </player> <passwordtextbox> <end_comp>
# <start_comp> <player> random_player_source </player> <video_player> string0 </video_player> <textbox> <textbox> <text2speech> <end_comp>
# <start_comp> <player> string0 </player> <end_comp>
# <start_comp> <ball> <player> string0 </player> <switch> switch1 </switch> <label> string1 </label> <video_player> random_video_player_source </video_player> <timepicker> <end_comp> <code> <ball1reach_edge> <label1> <time1> </label1> </ball1reach_edge> <switch1flipped> <video_player1> <stop> </video_player1> </switch1flipped> </code>
# <start_comp> <ball> <video_player> string0 </video_player> <video_player> string1 </video_player> <player> random_player_source </player> <accelerometer> <end_comp> <code> <ball1reach_edge> <player1> <stop> </player1> </ball1reach_edge> <accelerometer1shaken> <video_player1> <stop> </video_player1> </accelerometer1shaken> </code>
# <start_comp> <label> label1 </label> <accelerometer> <player> string0 </player> <ball> <button> button1 </button> <switch> switch1 </switch> <end_comp> <code> <accelerometer1shaken> <ball1> <bounce> </ball1> </accelerometer1shaken> <ball1reach_edge> <player1> <start> </player1> </ball1reach_edge> <button1clicked> <label1> string1 </label1> </button1clicked> </code>
# <start_comp> <accelerometer> <text2speech> <button> button1 </button> <player> string0 </player> <ball> <end_comp> <code> <accelerometer1shaken> <player1> <start> </player1> </accelerometer1shaken> <button1clicked> <ball1> <radius> number0 </radius> </ball1> </button1clicked> <ball1flung> <text2speech1> string1 </text2speech1> </ball1flung> </code>
# <start_comp> <video_player> string0 </video_player> <player> string1 </player> <player> string2 </player> <end_comp>
# <start_comp> <timepicker> <player> string0 </player> <passwordtextbox> <switch> switch1 </switch> <end_comp> <code> <switch1flipped> <player1> <stop> </player1> </switch1flipped> </code>
# <start_comp> <accelerometer> <textbox> <textbox> <player> string0 </player> <text2speech> <ball> <end_comp> <code> <accelerometer1shaken> <text2speech1> <textboxtext1> </text2speech1> </accelerometer1shaken> </code>
# <start_comp> <passwordtextbox> <timepicker> <textbox> <player> string0 </player> <end_comp>
# <start_comp> <ball> <text2speech> <video_player> string0 </video_player> <player> string1 </player> <timepicker> <end_comp> <code> <ball1flung> <player1> <stop> </player1> </ball1flung> </code>
# <start_comp> <button> button1 </button> <player> string0 </player> <video_player> string1 </video_player> <accelerometer> <textbox> <end_comp> <code> <button1clicked> <player1> <start> </player1> </button1clicked> <accelerometer1shaken> <video_player1> <stop> </video_player1> </accelerometer1shaken> </code>
# <start_comp> <label> label1 </label> <switch> switch1 </switch> <switch> string0 </switch> <label> label2 </label> <textbox> <player> random_player_source </player> <timepicker> <end_comp> <code> <switch1flipped> <label1> string1 </label1> </switch1flipped> <switch2flipped> <player1> <stop> </player1> </switch2flipped> </code>
# <start_comp> <button> button1 </button> <accelerometer> <switch> switch1 </switch> <player> string0 </player> <text2speech> <end_comp> <code> <button1clicked> <player1> <stop> </player1> </button1clicked> <accelerometer1shaken> <text2speech1> string1 </text2speech1> </accelerometer1shaken> </code>
# <start_comp> <player> random_player_source </player> <passwordtextbox> <textbox> <ball> <end_comp> <code> <ball1reach_edge> <ball1> <heading> number0 </heading> </ball1> </ball1reach_edge> </code>
# <start_comp> <player> string0 </player> <player> string1 </player> <passwordtextbox> <end_comp>
# <start_comp> <button> button1 </button> <timepicker> <textbox> <player> string0 </player> <accelerometer> <ball> <video_player> random_video_player_source </video_player> <end_comp> <code> <button1clicked> <ball1> <color> <light_gray> </color> </ball1> </button1clicked> <accelerometer1shaken> <video_player1> <start> </video_player1> </accelerometer1shaken> <ball1reach_edge> <player1> <start> </player1> </ball1reach_edge> </code>
# <start_comp> <text2speech> <passwordtextbox> <player> string0 </player> <accelerometer> <passwordtextbox> <player> string1 </player> <textbox> <end_comp> <code> <accelerometer1shaken> <player1> <start> </player1> </accelerometer1shaken> </code>
# <start_comp> <passwordtextbox> <switch> string0 </switch> <player> string1 </player> <accelerometer> <textbox> <button> string2 </button> <end_comp> <code> <switch1flipped> <player1> <stop> </player1> </switch1flipped> </code>
# <start_comp> <player> string0 </player> <timepicker> <video_player> random_video_player_source </video_player> <textbox> <end_comp>
# <start_comp> <player> string0 </player> <text2speech> <end_comp>
# <start_comp> <switch> switch1 </switch> <switch> switch2 </switch> <timepicker> <player> string0 </player> <label> string1 </label> <end_comp> <code> <switch1flipped> <label1> <time1> </label1> </switch1flipped> <switch2flipped> <player1> <stop> </player1> </switch2flipped> </code>
# <start_comp> <ball> <player> string0 </player> <label> label1 </label> <player> string1 </player> <textbox> <timepicker> <end_comp> <code> <ball1flung> <player1> <stop> </player1> </ball1flung> </code>
# <start_comp> <player> random_player_source </player> <switch> switch1 </switch> <button> button1 </button> <textbox> <passwordtextbox> <button> button2 </button> <end_comp> <code> <switch1flipped> <player1> <start> </player1> </switch1flipped> </code>
# <start_comp> <switch> switch1 </switch> <label> label1 </label> <ball> <player> random_player_source </player> <video_player> random_video_player_source </video_player> <end_comp> <code> <switch1flipped> <ball1> <speed> number0 </speed> </ball1> </switch1flipped> <ball1reach_edge> <video_player1> <start> </video_player1> </ball1reach_edge> </code>
# <start_comp> <switch> switch1 </switch> <passwordtextbox> <timepicker> <player> string0 </player> <end_comp> <code> <switch1flipped> <player1> <stop> </player1> </switch1flipped> </code>
# <start_comp> <player> random_player_source </player> <video_player> string0 </video_player> <passwordtextbox> <switch> switch1 </switch> <accelerometer> <button> string1 </button> <ball> <end_comp> <code> <switch1flipped> <ball1> <motion> </ball1> </switch1flipped> <accelerometer1shaken> <video_player1> <stop> </video_player1> </accelerometer1shaken> <button1clicked> <player1> <start> </player1> </button1clicked> </code>
# <start_comp> <player> string0 </player> <switch> switch1 </switch> <timepicker> <end_comp> <code> <switch1flipped> <player1> <stop> </player1> </switch1flipped> </code>
# <start_comp> <video_player> random_video_player_source </video_player> <timepicker> <accelerometer> <player> string0 </player> <textbox> <ball> <text2speech> <end_comp> <code> <accelerometer1shaken> <video_player1> <start> </video_player1> </accelerometer1shaken> <ball1reach_edge> <player1> <stop> </player1> </ball1reach_edge> </code>
# <start_comp> <accelerometer> <text2speech> <player> string0 </player> <label> label1 </label> <end_comp> <code> <accelerometer1shaken> <player1> <stop> </player1> </accelerometer1shaken> </code>
# <start_comp> <accelerometer> <player> string0 </player> <textbox> <passwordtextbox> <switch> switch1 </switch> <end_comp> <code> <accelerometer1shaken> <player1> <start> </player1> </accelerometer1shaken> </code>
# <start_comp> <timepicker> <switch> switch1 </switch> <accelerometer> <player> string0 </player> <video_player> string1 </video_player> <button> button1 </button> <video_player> string2 </video_player> <end_comp> <code> <switch1flipped> <video_player1> <start> </video_player1> </switch1flipped> <accelerometer1shaken> <player1> <stop> </player1> </accelerometer1shaken> <button1clicked> <video_player2> <stop> </video_player2> </button1clicked> </code>
# <start_comp> <passwordtextbox> <button> string0 </button> <player> string1 </player> <video_player> string2 </video_player> <switch> switch1 </switch> <label> label1 </label> <accelerometer> <end_comp> <code> <button1clicked> <video_player1> <stop> </video_player1> </button1clicked> <switch1flipped> <player1> <start> </player1> </switch1flipped> <accelerometer1shaken> <label1> string3 </label1> </accelerometer1shaken> </code>
# <start_comp> <player> random_player_source </player> <text2speech> <accelerometer> <ball> <end_comp> <code> <accelerometer1shaken> <player1> <stop> </player1> </accelerometer1shaken> <ball1flung> <ball1> <color> <orange> </color> </ball1> </ball1flung> </code>
# <start_comp> <player> string0 </player> <textbox> <end_comp>
# <start_comp> <label> string0 </label> <switch> switch1 </switch> <player> random_player_source </player> <ball> <end_comp> <code> <switch1flipped> <ball1> <bounce> </ball1> </switch1flipped> <ball1reach_edge> <label1> string1 </label1> </ball1reach_edge> </code>
# <start_comp> <textbox> <player> string0 </player> <accelerometer> <end_comp> <code> <accelerometer1shaken> <player1> <start> </player1> </accelerometer1shaken> </code>
# <start_comp> <ball> <player> random_player_source </player> <end_comp> <code> <ball1flung> <player1> <start> </player1> </ball1flung> </code>
# <start_comp> <player> string0 </player> <end_comp>
# <start_comp> <timepicker> <player> string0 </player> <player> string1 </player> <textbox> <textbox> <accelerometer> <end_comp> <code> <accelerometer1shaken> <player1> <stop> </player1> </accelerometer1shaken> </code>
# <start_comp> <player> string0 </player> <accelerometer> <passwordtextbox> <textbox> <end_comp> <code> <accelerometer1shaken> <player1> <start> </player1> </accelerometer1shaken> </code>
# <start_comp> <video_player> string0 </video_player> <ball> <player> string1 </player> <accelerometer> <timepicker> <textbox> <end_comp> <code> <ball1flung> <player1> <start> </player1> </ball1flung> <accelerometer1shaken> <ball1> <heading> number0 </heading> </ball1> </accelerometer1shaken> </code>
# <start_comp> <passwordtextbox> <timepicker> <passwordtextbox> <textbox> <player> string0 </player> <end_comp>
# <start_comp> <player> random_player_source </player> <video_player> string0 </video_player> <button> button1 </button> <button> button2 </button> <timepicker> <end_comp> <code> <button1clicked> <video_player1> <start> </video_player1> </button1clicked> <button2clicked> <player1> <stop> </player1> </button2clicked> </code>
# <start_comp> <player> string0 </player> <ball> <end_comp> <code> <ball1reach_edge> <player1> <stop> </player1> </ball1reach_edge> </code>
# <start_comp> <ball> <player> random_player_source </player> <button> button1 </button> <end_comp> <code> <ball1flung> <player1> <start> </player1> </ball1flung> <button1clicked> <ball1> <heading> number0 </heading> </ball1> </button1clicked> </code>
# <start_comp> <timepicker> <textbox> <accelerometer> <button> button1 </button> <player> string0 </player> <video_player> string1 </video_player> <end_comp> <code> <accelerometer1shaken> <video_player1> <stop> </video_player1> </accelerometer1shaken> <button1clicked> <player1> <start> </player1> </button1clicked> </code>
# <start_comp> <player> random_player_source </player> <textbox> <end_comp>
# <start_comp> <text2speech> <textbox> <player> string0 </player> <passwordtextbox> <ball> <player> string1 </player> <button> button1 </button> <end_comp> <code> <ball1flung> <player1> <start> </player1> </ball1flung> <button1clicked> <player2> <start> </player2> </button1clicked> </code>
# <start_comp> <button> button1 </button> <accelerometer> <timepicker> <text2speech> <player> string0 </player> <end_comp> <code> <button1clicked> <player1> <start> </player1> </button1clicked> <accelerometer1shaken> <text2speech1> string1 </text2speech1> </accelerometer1shaken> </code>
# <start_comp> <player> random_player_source </player> <timepicker> <button> button1 </button> <player> random_player_source </player> <button> string0 </button> <textbox> <text2speech> <end_comp> <code> <button1clicked> <player1> <stop> </player1> </button1clicked> <button2clicked> <text2speech1> <time1> </text2speech1> </button2clicked> </code>
# <start_comp> <label> label1 </label> <switch> string0 </switch> <player> random_player_source </player> <text2speech> <ball> <end_comp> <code> <switch1flipped> <ball1> <radius> number0 </radius> </ball1> </switch1flipped> <ball1reach_edge> <player1> <stop> </player1> </ball1reach_edge> </code>
# <start_comp> <player> string0 </player> <button> button1 </button> <textbox> <end_comp> <code> <button1clicked> <player1> <start> </player1> </button1clicked> </code>
# <start_comp> <player> string0 </player> <end_comp>
# <start_comp> <timepicker> <player> random_player_source </player> <end_comp>
# <start_comp> <player> string0 </player> <player> string1 </player> <switch> switch1 </switch> <accelerometer> <textbox> <passwordtextbox> <end_comp> <code> <switch1flipped> <player1> <stop> </player1> </switch1flipped> <accelerometer1shaken> <player2> <start> </player2> </accelerometer1shaken> </code>
# <start_comp> <player> random_player_source </player> <end_comp>
# <start_comp> <button> button1 </button> <ball> <timepicker> <switch> switch1 </switch> <player> string0 </player> <label> label1 </label> <passwordtextbox> <end_comp> <code> <button1clicked> <label1> <time1> </label1> </button1clicked> <ball1flung> <ball1> <speed> number0 </speed> </ball1> </ball1flung> <switch1flipped> <player1> <start> </player1> </switch1flipped> </code>
# <start_comp> <passwordtextbox> <player> string0 </player> <ball> <button> string1 </button> <end_comp> <code> <ball1reach_edge> <player1> <start> </player1> </ball1reach_edge> <button1clicked> <ball1> <heading> number0 </heading> </ball1> </button1clicked> </code>
# <start_comp> <textbox> <ball> <label> string0 </label> <video_player> random_video_player_source </video_player> <accelerometer> <player> string1 </player> <player> string2 </player> <end_comp> <code> <ball1flung> <player1> <start> </player1> </ball1flung> <accelerometer1shaken> <label1> <textboxtext1> </label1> </accelerometer1shaken> </code>
# <start_comp> <text2speech> <label> label1 </label> <player> string0 </player> <passwordtextbox> <switch> switch1 </switch> <passwordtextbox> <end_comp> <code> <switch1flipped> <player1> <stop> </player1> </switch1flipped> </code>
# <start_comp> <timepicker> <passwordtextbox> <ball> <player> random_player_source </player> <text2speech> <end_comp> <code> <ball1reach_edge> <player1> <start> </player1> </ball1reach_edge> </code>
# <start_comp> <player> string0 </player> <passwordtextbox> <switch> string1 </switch> <textbox> <switch> switch2 </switch> <timepicker> <button> button1 </button> <end_comp> <code> <switch1flipped> <player1> <stop> </player1> </switch1flipped> </code>
# <start_comp> <text2speech> <player> string0 </player> <textbox> <video_player> string1 </video_player> <button> button1 </button> <timepicker> <passwordtextbox> <end_comp> <code> <button1clicked> <video_player1> <stop> </video_player1> </button1clicked> </code>
# <start_comp> <player> string0 </player> <end_comp>
# <start_comp> <player> string0 </player> <ball> <button> string1 </button> <timepicker> <passwordtextbox> <label> label1 </label> <end_comp> <code> <ball1flung> <player1> <start> </player1> </ball1flung> <button1clicked> <ball1> <heading> number0 </heading> </ball1> </button1clicked> </code>
# <start_comp> <timepicker> <text2speech> <video_player> string0 </video_player> <player> string1 </player> <switch> switch1 </switch> <button> string2 </button> <end_comp> <code> <switch1flipped> <player1> <start> </player1> </switch1flipped> <button1clicked> <text2speech1> <time1> </text2speech1> </button1clicked> </code>
# <start_comp> <ball> <player> string0 </player> <button> string1 </button> <video_player> string2 </video_player> <switch> switch1 </switch> <video_player> string3 </video_player> <text2speech> <end_comp> <code> <ball1flung> <video_player1> <start> </video_player1> </ball1flung> <button1clicked> <ball1> <radius> number0 </radius> </ball1> </button1clicked> <switch1flipped> <video_player2> <stop> </video_player2> </switch1flipped> </code>
# <start_comp> <player> string0 </player> <video_player> string1 </video_player> <end_comp>
# <start_comp> <player> string0 </player> <text2speech> <accelerometer> <passwordtextbox> <end_comp> <code> <accelerometer1shaken> <player1> <start> </player1> </accelerometer1shaken> </code>
# <start_comp> <switch> switch1 </switch> <text2speech> <button> button1 </button> <ball> <button> button2 </button> <player> string0 </player> <end_comp> <code> <switch1flipped> <text2speech1> string1 </text2speech1> </switch1flipped> <button1clicked> <player1> <stop> </player1> </button1clicked> <ball1flung> <ball1> <bounce> </ball1> </ball1flung> </code>
# <start_comp> <label> label1 </label> <player> random_player_source </player> <timepicker> <passwordtextbox> <player> random_player_source </player> <accelerometer> <end_comp> <code> <accelerometer1shaken> <label1> <time1> </label1> </accelerometer1shaken> </code>
# <start_comp> <player> string0 </player> <player> string1 </player> <end_comp>
# <start_comp> <button> string0 </button> <player> string1 </player> <textbox> <accelerometer> <timepicker> <end_comp> <code> <accelerometer1shaken> <player1> <start> </player1> </accelerometer1shaken> </code>
# <start_comp> <label> label1 </label> <player> string0 </player> <end_comp>
# <start_comp> <label> label1 </label> <passwordtextbox> <video_player> string0 </video_player> <passwordtextbox> <player> string1 </player> <video_player> random_video_player_source </video_player> <end_comp>
# <start_comp> <text2speech> <player> string0 </player> <button> button1 </button> <label> label1 </label> <video_player> string1 </video_player> <textbox> <switch> switch1 </switch> <end_comp> <code> <button1clicked> <label1> string2 </label1> </button1clicked> <switch1flipped> <text2speech1> <textboxtext1> </text2speech1> </switch1flipped> </code>
# <start_comp> <passwordtextbox> <label> label1 </label> <player> string0 </player> <button> string1 </button> <end_comp> <code> <button1clicked> <player1> <stop> </player1> </button1clicked> </code>
# <start_comp> <player> string0 </player> <label> label1 </label> <timepicker> <textbox> <switch> switch1 </switch> <end_comp> <code> <switch1flipped> <player1> <stop> </player1> </switch1flipped> </code>
# <start_comp> <switch> switch1 </switch> <player> random_player_source </player> <player> string0 </player> <text2speech> <video_player> string1 </video_player> <passwordtextbox> <end_comp> <code> <switch1flipped> <player1> <start> </player1> </switch1flipped> </code>
# <start_comp> <button> button1 </button> <text2speech> <ball> <video_player> string0 </video_player> <switch> switch1 </switch> <accelerometer> <player> string1 </player> <end_comp> <code> <button1clicked> <text2speech1> string2 </text2speech1> </button1clicked> <ball1flung> <video_player1> <start> </video_player1> </ball1flung> <switch1flipped> <player1> <stop> </player1> </switch1flipped> <accelerometer1shaken> <ball1> <bounce> </ball1> </accelerometer1shaken> </code>
# <start_comp> <player> string0 </player> <end_comp>
# <start_comp> <passwordtextbox> <switch> switch1 </switch> <ball> <player> string0 </player> <accelerometer> <text2speech> <label> string1 </label> <end_comp> <code> <switch1flipped> <ball1> <motion> </ball1> </switch1flipped> <ball1reach_edge> <text2speech1> string2 </text2speech1> </ball1reach_edge> <accelerometer1shaken> <player1> <stop> </player1> </accelerometer1shaken> </code>
# <start_comp> <label> label1 </label> <player> string0 </player> <end_comp>
# <start_comp> <accelerometer> <textbox> <video_player> string0 </video_player> <player> random_player_source </player> <button> button1 </button> <player> string1 </player> <end_comp> <code> <accelerometer1shaken> <video_player1> <stop> </video_player1> </accelerometer1shaken> <button1clicked> <player1> <stop> </player1> </button1clicked> </code>
# <start_comp> <label> label1 </label> <player> string0 </player> <player> string1 </player> <end_comp>
# <start_comp> <label> string0 </label> <passwordtextbox> <ball> <player> string1 </player> <end_comp> <code> <ball1flung> <label1> string2 </label1> </ball1flung> </code>
# <start_comp> <player> random_player_source </player> <ball> <end_comp> <code> <ball1reach_edge> <ball1> <heading> number0 </heading> </ball1> </ball1reach_edge> </code>
# <start_comp> <ball> <passwordtextbox> <player> string0 </player> <text2speech> <end_comp> <code> <ball1flung> <player1> <stop> </player1> </ball1flung> </code>
# <start_comp> <video_player> string0 </video_player> <label> label1 </label> <timepicker> <player> string1 </player> <button> button1 </button> <ball> <end_comp> <code> <button1clicked> <label1> <time1> </label1> </button1clicked> <ball1reach_edge> <video_player1> <start> </video_player1> </ball1reach_edge> </code>
# <start_comp> <player> string0 </player> <textbox> <switch> switch1 </switch> <ball> <video_player> random_video_player_source </video_player> <passwordtextbox> <button> button1 </button> <end_comp> <code> <switch1flipped> <ball1> <motion> </ball1> </switch1flipped> <ball1flung> <video_player1> <stop> </video_player1> </ball1flung> <button1clicked> <player1> <stop> </player1> </button1clicked> </code>
# <start_comp> <player> random_player_source </player> <end_comp>
# <start_comp> <passwordtextbox> <player> random_player_source </player> <ball> <textbox> <end_comp> <code> <ball1reach_edge> <ball1> <speed> number0 </speed> </ball1> </ball1reach_edge> </code>
# <start_comp> <accelerometer> <switch> switch1 </switch> <text2speech> <player> string0 </player> <timepicker> <end_comp> <code> <accelerometer1shaken> <text2speech1> <time1> </text2speech1> </accelerometer1shaken> </code>
# <start_comp> <player> string0 </player> <button> button1 </button> <text2speech> <end_comp> <code> <button1clicked> <text2speech1> string1 </text2speech1> </button1clicked> </code>
# <start_comp> <ball> <accelerometer> <video_player> string0 </video_player> <player> string1 </player> <end_comp> <code> <ball1flung> <ball1> <motion> </ball1> </ball1flung> <accelerometer1shaken> <player1> <start> </player1> </accelerometer1shaken> </code>
# <start_comp> <ball> <player> random_player_source </player> <timepicker> <switch> switch1 </switch> <end_comp> <code> <ball1flung> <player1> <stop> </player1> </ball1flung> <switch1flipped> <ball1> <bounce> </ball1> </switch1flipped> </code>
# <start_comp> <textbox> <button> string0 </button> <accelerometer> <button> button2 </button> <switch> switch1 </switch> <timepicker> <player> random_player_source </player> <end_comp> <code> <button1clicked> <player1> <start> </player1> </button1clicked> </code>
# <start_comp> <text2speech> <ball> <player> string0 </player> <textbox> <button> button1 </button> <end_comp> <code> <ball1flung> <ball1> <color> <blue> </color> </ball1> </ball1flung> <button1clicked> <player1> <stop> </player1> </button1clicked> </code>
# <start_comp> <player> string0 </player> <label> label1 </label> <switch> switch1 </switch> <text2speech> <video_player> string1 </video_player> <switch> string2 </switch> <end_comp> <code> <switch1flipped> <video_player1> <stop> </video_player1> </switch1flipped> <switch2flipped> <player1> <stop> </player1> </switch2flipped> </code>
# <start_comp> <player> string0 </player> <switch> switch1 </switch> <end_comp> <code> <switch1flipped> <player1> <stop> </player1> </switch1flipped> </code>
# <start_comp> <video_player> string0 </video_player> <textbox> <player> string1 </player> <accelerometer> <textbox> <text2speech> <passwordtextbox> <end_comp> <code> <accelerometer1shaken> <player1> <stop> </player1> </accelerometer1shaken> </code>
# <start_comp> <player> string0 </player> <video_player> string1 </video_player> <accelerometer> <ball> <passwordtextbox> <end_comp> <code> <ball1reach_edge> <ball1> <speed> number0 </speed> </ball1> </ball1reach_edge> <accelerometer1shaken> <player1> <start> </player1> </accelerometer1shaken> </code>
# <start_comp> <accelerometer> <switch> switch1 </switch> <player> random_player_source </player> <label> label1 </label> <player> string0 </player> <end_comp> <code> <accelerometer1shaken> <player1> <stop> </player1> </accelerometer1shaken> <switch1flipped> <player2> <start> </player2> </switch1flipped> </code>
# <start_comp> <label> string0 </label> <accelerometer> <player> string1 </player> <passwordtextbox> <end_comp> <code> <accelerometer1shaken> <label1> string2 </label1> </accelerometer1shaken> </code>
# <start_comp> <player> string0 </player> <video_player> string1 </video_player> <accelerometer> <end_comp> <code> <accelerometer1shaken> <player1> <stop> </player1> </accelerometer1shaken> </code>
# <start_comp> <video_player> string0 </video_player> <ball> <timepicker> <video_player> random_video_player_source </video_player> <player> random_player_source </player> <label> label1 </label> <passwordtextbox> <end_comp> <code> <ball1reach_edge> <video_player1> <stop> </video_player1> </ball1reach_edge> </code>
# <start_comp> <text2speech> <textbox> <player> string0 </player> <passwordtextbox> <switch> switch1 </switch> <label> label1 </label> <end_comp> <code> <switch1flipped> <text2speech1> <textboxtext1> </text2speech1> </switch1flipped> </code>
# <start_comp> <timepicker> <textbox> <player> string0 </player> <video_player> string1 </video_player> <timepicker> <player> string2 </player> <label> label1 </label> <end_comp>
# <start_comp> <ball> <accelerometer> <label> label1 </label> <player> string0 </player> <video_player> string1 </video_player> <end_comp> <code> <ball1flung> <video_player1> <start> </video_player1> </ball1flung> <accelerometer1shaken> <label1> string2 </label1> </accelerometer1shaken> </code>
# <start_comp> <textbox> <switch> switch1 </switch> <label> label1 </label> <player> string0 </player> <end_comp> <code> <switch1flipped> <player1> <start> </player1> </switch1flipped> </code>
# <start_comp> <switch> switch1 </switch> <player> string0 </player> <textbox> <textbox> <video_player> random_video_player_source </video_player> <text2speech> <textbox> <end_comp> <code> <switch1flipped> <text2speech1> string1 </text2speech1> </switch1flipped> </code>
# <start_comp> <button> string0 </button> <ball> <textbox> <passwordtextbox> <player> string1 </player> <video_player> random_video_player_source </video_player> <end_comp> <code> <button1clicked> <player1> <stop> </player1> </button1clicked> <ball1reach_edge> <video_player1> <stop> </video_player1> </ball1reach_edge> </code>
# <start_comp> <timepicker> <textbox> <ball> <switch> string0 </switch> <player> string1 </player> <switch> string2 </switch> <timepicker> <end_comp> <code> <ball1reach_edge> <player1> <stop> </player1> </ball1reach_edge> <switch1flipped> <ball1> <motion> </ball1> </switch1flipped> </code>
# <start_comp> <text2speech> <textbox> <player> string0 </player> <video_player> string1 </video_player> <button> button1 </button> <video_player> string2 </video_player> <end_comp> <code> <button1clicked> <text2speech1> <textboxtext1> </text2speech1> </button1clicked> </code>
# <start_comp> <button> button1 </button> <button> string0 </button> <accelerometer> <player> string1 </player> <video_player> string2 </video_player> <end_comp> <code> <button1clicked> <video_player1> <stop> </video_player1> </button1clicked> </code>
# <start_comp> <switch> switch1 </switch> <passwordtextbox> <video_player> random_video_player_source </video_player> <accelerometer> <button> string0 </button> <player> random_player_source </player> <end_comp> <code> <switch1flipped> <player1> <stop> </player1> </switch1flipped> <accelerometer1shaken> <video_player1> <start> </video_player1> </accelerometer1shaken> </code>
# <start_comp> <timepicker> <player> string0 </player> <button> string1 </button> <passwordtextbox> <video_player> string2 </video_player> <text2speech> <ball> <end_comp> <code> <button1clicked> <text2speech1> <time1> </text2speech1> </button1clicked> <ball1reach_edge> <video_player1> <stop> </video_player1> </ball1reach_edge> </code>
# <start_comp> <passwordtextbox> <player> random_player_source </player> <player> string0 </player> <timepicker> <switch> switch1 </switch> <switch> switch2 </switch> <button> button1 </button> <end_comp> <code> <switch1flipped> <player1> <stop> </player1> </switch1flipped> <switch2flipped> <player2> <stop> </player2> </switch2flipped> </code>
# <start_comp> <passwordtextbox> <player> string0 </player> <end_comp>
# <start_comp> <video_player> string0 </video_player> <player> string1 </player> <textbox> <button> button1 </button> <button> button2 </button> <text2speech> <timepicker> <end_comp> <code> <button1clicked> <player1> <start> </player1> </button1clicked> <button2clicked> <text2speech1> <textboxtext1> </text2speech1> </button2clicked> </code>
# <start_comp> <button> string0 </button> <timepicker> <textbox> <label> label1 </label> <player> string1 </player> <accelerometer> <ball> <end_comp> <code> <button1clicked> <ball1> <bounce> </ball1> </button1clicked> <accelerometer1shaken> <label1> <textboxtext1> </label1> </accelerometer1shaken> <ball1flung> <player1> <start> </player1> </ball1flung> </code>
# <start_comp> <passwordtextbox> <accelerometer> <textbox> <video_player> string0 </video_player> <text2speech> <player> string1 </player> <end_comp> <code> <accelerometer1shaken> <text2speech1> <textboxtext1> </text2speech1> </accelerometer1shaken> </code>
# <start_comp> <player> string0 </player> <ball> <timepicker> <accelerometer> <switch> switch1 </switch> <switch> string1 </switch> <end_comp> <code> <ball1flung> <player1> <stop> </player1> </ball1flung> <accelerometer1shaken> <ball1> <speed> number0 </speed> </ball1> </accelerometer1shaken> </code>
# <start_comp> <player> string0 </player> <text2speech> <timepicker> <button> string1 </button> <end_comp> <code> <button1clicked> <player1> <start> </player1> </button1clicked> </code>
# <start_comp> <label> label1 </label> <player> random_player_source </player> <textbox> <end_comp>
# <start_comp> <text2speech> <switch> switch1 </switch> <player> string0 </player> <timepicker> <player> string1 </player> <accelerometer> <video_player> string2 </video_player> <end_comp> <code> <switch1flipped> <player1> <start> </player1> </switch1flipped> <accelerometer1shaken> <video_player1> <start> </video_player1> </accelerometer1shaken> </code>
# <start_comp> <ball> <player> string0 </player> <textbox> <accelerometer> <end_comp> <code> <ball1reach_edge> <player1> <stop> </player1> </ball1reach_edge> <accelerometer1shaken> <ball1> <motion> </ball1> </accelerometer1shaken> </code>
# <start_comp> <video_player> string0 </video_player> <label> label1 </label> <player> string1 </player> <textbox> <switch> string2 </switch> <passwordtextbox> <end_comp> <code> <switch1flipped> <player1> <start> </player1> </switch1flipped> </code>
# <start_comp> <timepicker> <switch> string0 </switch> <player> random_player_source </player> <end_comp> <code> <switch1flipped> <player1> <stop> </player1> </switch1flipped> </code>
# <start_comp> <player> random_player_source </player> <passwordtextbox> <end_comp>
# <start_comp> <player> string0 </player> <text2speech> <passwordtextbox> <timepicker> <end_comp>
# <start_comp> <video_player> string0 </video_player> <player> string1 </player> <label> label1 </label> <button> button1 </button> <text2speech> <end_comp> <code> <button1clicked> <text2speech1> string2 </text2speech1> </button1clicked> </code>
# <start_comp> <ball> <player> string0 </player> <label> string1 </label> <button> button1 </button> <player> string2 </player> <switch> switch1 </switch> <end_comp> <code> <ball1reach_edge> <player1> <stop> </player1> </ball1reach_edge> <button1clicked> <label1> string3 </label1> </button1clicked> <switch1flipped> <ball1> <radius> number0 </radius> </ball1> </switch1flipped> </code>
# <start_comp> <accelerometer> <textbox> <player> string0 </player> <timepicker> <end_comp> <code> <accelerometer1shaken> <player1> <stop> </player1> </accelerometer1shaken> </code>
# <start_comp> <player> string0 </player> <label> label1 </label> <accelerometer> <textbox> <button> string1 </button> <end_comp> <code> <accelerometer1shaken> <player1> <start> </player1> </accelerometer1shaken> <button1clicked> <label1> <textboxtext1> </label1> </button1clicked> </code>
# <start_comp> <video_player> string0 </video_player> <button> button1 </button> <label> label1 </label> <player> random_player_source </player> <ball> <accelerometer> <end_comp> <code> <button1clicked> <label1> string1 </label1> </button1clicked> <ball1flung> <video_player1> <stop> </video_player1> </ball1flung> <accelerometer1shaken> <ball1> <bounce> </ball1> </accelerometer1shaken> </code>
# <start_comp> <button> button1 </button> <ball> <accelerometer> <textbox> <player> string0 </player> <passwordtextbox> <end_comp> <code> <button1clicked> <ball1> <color> <gray> </color> </ball1> </button1clicked> <ball1reach_edge> <player1> <start> </player1> </ball1reach_edge> </code>
# <start_comp> <switch> string0 </switch> <button> string1 </button> <player> string2 </player> <player> string3 </player> <end_comp> <code> <switch1flipped> <player1> <start> </player1> </switch1flipped> <button1clicked> <player2> <stop> </player2> </button1clicked> </code>
# <start_comp> <switch> switch1 </switch> <ball> <textbox> <player> string0 </player> <text2speech> <label> label1 </label> <textbox> <end_comp> <code> <switch1flipped> <ball1> <motion> </ball1> </switch1flipped> <ball1flung> <text2speech1> string1 </text2speech1> </ball1flung> </code>
# <start_comp> <player> string0 </player> <label> label1 </label> <accelerometer> <text2speech> <end_comp> <code> <accelerometer1shaken> <player1> <stop> </player1> </accelerometer1shaken> </code>
# <start_comp> <player> string0 </player> <passwordtextbox> <passwordtextbox> <timepicker> <button> string1 </button> <switch> switch1 </switch> <textbox> <end_comp> <code> <button1clicked> <player1> <start> </player1> </button1clicked> </code>
# <start_comp> <textbox> <player> random_player_source </player> <end_comp>
# <start_comp> <textbox> <player> string0 </player> <ball> <accelerometer> <label> label1 </label> <video_player> string1 </video_player> <end_comp> <code> <ball1reach_edge> <label1> string2 </label1> </ball1reach_edge> </code>
# <start_comp> <timepicker> <passwordtextbox> <player> string0 </player> <textbox> <end_comp>
# <start_comp> <text2speech> <switch> switch1 </switch> <player> string0 </player> <passwordtextbox> <button> button1 </button> <video_player> string1 </video_player> <end_comp> <code> <switch1flipped> <player1> <stop> </player1> </switch1flipped> <button1clicked> <text2speech1> string2 </text2speech1> </button1clicked> </code>
# <start_comp> <video_player> random_video_player_source </video_player> <passwordtextbox> <player> string0 </player> <timepicker> <accelerometer> <ball> <end_comp> <code> <accelerometer1shaken> <player1> <stop> </player1> </accelerometer1shaken> <ball1reach_edge> <ball1> <bounce> </ball1> </ball1reach_edge> </code>
# <start_comp> <label> label1 </label> <ball> <text2speech> <player> random_player_source </player> <video_player> string0 </video_player> <player> string1 </player> <end_comp> <code> <ball1flung> <label1> string2 </label1> </ball1flung> </code>
# <start_comp> <passwordtextbox> <accelerometer> <player> string0 </player> <end_comp> <code> <accelerometer1shaken> <player1> <stop> </player1> </accelerometer1shaken> </code>
# <start_comp> <textbox> <label> label1 </label> <button> button1 </button> <timepicker> <label> label2 </label> <player> string0 </player> <textbox> <end_comp> <code> <button1clicked> <player1> <stop> </player1> </button1clicked> </code>
# <start_comp> <ball> <player> string0 </player> <label> string1 </label> <text2speech> <player> string2 </player> <end_comp> <code> <ball1reach_edge> <text2speech1> string3 </text2speech1> </ball1reach_edge> </code>
# <start_comp> <player> string0 </player> <end_comp>
# <start_comp> <accelerometer> <textbox> <player> string0 </player> <ball> <text2speech> <player> random_player_source </player> <end_comp> <code> <accelerometer1shaken> <player1> <stop> </player1> </accelerometer1shaken> <ball1flung> <player2> <stop> </player2> </ball1flung> </code>
# <start_comp> <player> string0 </player> <end_comp>
# <start_comp> <passwordtextbox> <player> random_player_source </player> <end_comp>
# <start_comp> <passwordtextbox> <player> random_player_source </player> <player> string0 </player> <button> button1 </button> <accelerometer> <switch> switch1 </switch> <end_comp> <code> <accelerometer1shaken> <player1> <start> </player1> </accelerometer1shaken> <button1clicked> <player2> <start> </player2> </button1clicked> </code>
# <start_comp> <player> string0 </player> <switch> string1 </switch> <timepicker> <label> label1 </label> <video_player> string2 </video_player> <end_comp> <code> <switch1flipped> <video_player1> <start> </video_player1> </switch1flipped> </code>
# <start_comp> <label> string0 </label> <player> string1 </player> <video_player> string2 </video_player> <switch> switch1 </switch> <switch> switch2 </switch> <accelerometer> <end_comp> <code> <switch1flipped> <player1> <stop> </player1> </switch1flipped> <switch2flipped> <label1> string3 </label1> </switch2flipped> <accelerometer1shaken> <video_player1> <stop> </video_player1> </accelerometer1shaken> </code>
# <start_comp> <player> random_player_source </player> <label> label1 </label> <textbox> <textbox> <button> string0 </button> <ball> <button> button2 </button> <end_comp> <code> <button1clicked> <label1> <textboxtext2> </label1> </button1clicked> <ball1flung> <player1> <stop> </player1> </ball1flung> <button2clicked> <ball1> <bounce> </ball1> </button2clicked> </code>
# <start_comp> <textbox> <video_player> random_video_player_source </video_player> <timepicker> <video_player> string0 </video_player> <player> string1 </player> <button> button1 </button> <end_comp> <code> <button1clicked> <player1> <stop> </player1> </button1clicked> </code>
# <start_comp> <timepicker> <label> label1 </label> <textbox> <textbox> <player> string0 </player> <accelerometer> <ball> <end_comp> <code> <accelerometer1shaken> <player1> <start> </player1> </accelerometer1shaken> <ball1flung> <ball1> <color> <dark_gray> </color> </ball1> </ball1flung> </code>
# <start_comp> <label> label1 </label> <button> button1 </button> <textbox> <accelerometer> <player> string0 </player> <end_comp> <code> <button1clicked> <label1> <textboxtext1> </label1> </button1clicked> <accelerometer1shaken> <player1> <start> </player1> </accelerometer1shaken> </code>
# <start_comp> <textbox> <passwordtextbox> <player> string0 </player> <switch> string1 </switch> <end_comp> <code> <switch1flipped> <player1> <stop> </player1> </switch1flipped> </code>
# <start_comp> <player> string0 </player> <passwordtextbox> <label> label1 </label> <button> button1 </button> <accelerometer> <ball> <end_comp> <code> <button1clicked> <label1> string1 </label1> </button1clicked> <accelerometer1shaken> <player1> <start> </player1> </accelerometer1shaken> </code>
# <start_comp> <label> label1 </label> <switch> switch1 </switch> <textbox> <button> button1 </button> <label> string0 </label> <player> string1 </player> <ball> <end_comp> <code> <switch1flipped> <player1> <stop> </player1> </switch1flipped> <button1clicked> <label1> <textboxtext1> </label1> </button1clicked> <ball1flung> <ball1> <radius> number0 </radius> </ball1> </ball1flung> </code>
# <start_comp> <player> string0 </player> <text2speech> <end_comp>
# <start_comp> <textbox> <ball> <button> button1 </button> <player> random_player_source </player> <end_comp> <code> <ball1flung> <player1> <stop> </player1> </ball1flung> <button1clicked> <ball1> <motion> </ball1> </button1clicked> </code>
# <start_comp> <textbox> <timepicker> <player> string0 </player> <video_player> random_video_player_source </video_player> <accelerometer> <passwordtextbox> <end_comp> <code> <accelerometer1shaken> <player1> <stop> </player1> </accelerometer1shaken> </code>
# <start_comp> <switch> switch1 </switch> <player> string0 </player> <button> button1 </button> <passwordtextbox> <text2speech> <timepicker> <end_comp> <code> <switch1flipped> <text2speech1> <time1> </text2speech1> </switch1flipped> <button1clicked> <player1> <start> </player1> </button1clicked> </code>
# <start_comp> <timepicker> <player> string0 </player> <timepicker> <end_comp>
# <start_comp> <player> string0 </player> <button> string1 </button> <timepicker> <button> button2 </button> <textbox> <ball> <end_comp> <code> <button1clicked> <player1> <start> </player1> </button1clicked> <button2clicked> <ball1> <motion> </ball1> </button2clicked> </code>
# <start_comp> <label> label1 </label> <player> random_player_source </player> <end_comp>
# <start_comp> <ball> <label> string0 </label> <player> string1 </player> <end_comp> <code> <ball1flung> <player1> <stop> </player1> </ball1flung> </code>
# <start_comp> <player> string0 </player> <label> label1 </label> <accelerometer> <ball> <end_comp> <code> <accelerometer1shaken> <player1> <start> </player1> </accelerometer1shaken> <ball1reach_edge> <label1> string1 </label1> </ball1reach_edge> </code>
# <start_comp> <player> random_player_source </player> <accelerometer> <timepicker> <passwordtextbox> <end_comp> <code> <accelerometer1shaken> <player1> <stop> </player1> </accelerometer1shaken> </code>
# <start_comp> <player> string0 </player> <text2speech> <player> string1 </player> <passwordtextbox> <video_player> string2 </video_player> <button> button1 </button> <textbox> <end_comp> <code> <button1clicked> <player1> <start> </player1> </button1clicked> </code>
# <start_comp> <text2speech> <player> string0 </player> <end_comp>
# <start_comp> <textbox> <passwordtextbox> <text2speech> <accelerometer> <player> string0 </player> <end_comp> <code> <accelerometer1shaken> <text2speech1> string1 </text2speech1> </accelerometer1shaken> </code>
# <start_comp> <passwordtextbox> <timepicker> <player> string0 </player> <passwordtextbox> <end_comp>
# <start_comp> <textbox> <player> random_player_source </player> <text2speech> <video_player> string0 </video_player> <timepicker> <end_comp>
# <start_comp> <player> string0 </player> <button> button1 </button> <accelerometer> <label> label1 </label> <label> label2 </label> <end_comp> <code> <button1clicked> <label1> string1 </label1> </button1clicked> <accelerometer1shaken> <player1> <start> </player1> </accelerometer1shaken> </code>
# <start_comp> <player> string0 </player> <textbox> <passwordtextbox> <timepicker> <video_player> string1 </video_player> <text2speech> <label> label1 </label> <end_comp>
# <start_comp> <label> string0 </label> <text2speech> <player> string1 </player> <passwordtextbox> <textbox> <textbox> <timepicker> <end_comp>
# <start_comp> <player> string0 </player> <switch> switch1 </switch> <timepicker> <text2speech> <end_comp> <code> <switch1flipped> <text2speech1> <time1> </text2speech1> </switch1flipped> </code>
# <start_comp> <ball> <accelerometer> <textbox> <label> string0 </label> <player> string1 </player> <end_comp> <code> <ball1flung> <ball1> <motion> </ball1> </ball1flung> <accelerometer1shaken> <label1> <textboxtext1> </label1> </accelerometer1shaken> </code>
# <start_comp> <player> string0 </player> <ball> <end_comp> <code> <ball1flung> <ball1> <color> <orange> </color> </ball1> </ball1flung> </code>
# <start_comp> <player> string0 </player> <timepicker> <timepicker> <text2speech> <end_comp>
# <start_comp> <player> random_player_source </player> <ball> <player> random_player_source </player> <accelerometer> <text2speech> <label> label1 </label> <textbox> <end_comp> <code> <ball1reach_edge> <ball1> <heading> number0 </heading> </ball1> </ball1reach_edge> <accelerometer1shaken> <player1> <stop> </player1> </accelerometer1shaken> </code>
# <start_comp> <text2speech> <textbox> <player> random_player_source </player> <ball> <end_comp> <code> <ball1flung> <player1> <stop> </player1> </ball1flung> </code>
# <start_comp> <timepicker> <video_player> string0 </video_player> <textbox> <button> button1 </button> <player> string1 </player> <accelerometer> <ball> <end_comp> <code> <button1clicked> <ball1> <bounce> </ball1> </button1clicked> <accelerometer1shaken> <player1> <start> </player1> </accelerometer1shaken> <ball1flung> <video_player1> <start> </video_player1> </ball1flung> </code>
# <start_comp> <button> button1 </button> <player> random_player_source </player> <accelerometer> <player> string0 </player> <video_player> string1 </video_player> <label> label1 </label> <switch> string2 </switch> <end_comp> <code> <button1clicked> <video_player1> <start> </video_player1> </button1clicked> <accelerometer1shaken> <player1> <stop> </player1> </accelerometer1shaken> <switch1flipped> <player2> <stop> </player2> </switch1flipped> </code>
# <start_comp> <timepicker> <textbox> <ball> <video_player> string0 </video_player> <button> button1 </button> <switch> switch1 </switch> <player> string1 </player> <end_comp> <code> <ball1flung> <player1> <stop> </player1> </ball1flung> <button1clicked> <ball1> <motion> </ball1> </button1clicked> <switch1flipped> <video_player1> <start> </video_player1> </switch1flipped> </code>
# <start_comp> <player> string0 </player> <textbox> <button> button1 </button> <text2speech> <player> random_player_source </player> <label> label1 </label> <passwordtextbox> <end_comp> <code> <button1clicked> <text2speech1> <textboxtext1> </text2speech1> </button1clicked> </code>
# <start_comp> <video_player> string0 </video_player> <player> string1 </player> <ball> <end_comp> <code> <ball1flung> <video_player1> <stop> </video_player1> </ball1flung> </code>
# ...
# <start_comp> <timepicker> <accelerometer> <text2speech> <player> string0 </player> <ball> <end_comp> <code> <accelerometer1shaken> <ball1> <speed> number0 </speed> </ball1> </accelerometer1shaken> <ball1flung> <text2speech1> <time1> </text2speech1> </ball1flung> </code>
# <start_comp> <player> string0 </player> <switch> switch1 </switch> <player> string1 </player> <end_comp> <code> <switch1flipped> <player1> <stop> </player1> </switch1flipped> </code>
# <start_comp> <text2speech> <passwordtextbox> <player> string0 </player> <end_comp>
# <start_comp> <video_player> string0 </video_player> <video_player> random_video_player_source </video_player> <timepicker> <passwordtextbox> <ball> <player> string1 </player> <switch> switch1 </switch> <end_comp> <code> <ball1flung> <player1> <start> </player1> </ball1flung> <switch1flipped> <video_player1> <stop> </video_player1> </switch1flipped> </code>
# <start_comp> <timepicker> <player> string0 </player> <video_player> random_video_player_source </video_player> <timepicker> <ball> <accelerometer> <end_comp> <code> <ball1reach_edge> <ball1> <bounce> </ball1> </ball1reach_edge> <accelerometer1shaken> <player1> <start> </player1> </accelerometer1shaken> </code>
# <start_comp> <video_player> string0 </video_player> <player> string1 </player> <timepicker> <switch> switch1 </switch> <text2speech> <end_comp> <code> <switch1flipped> <text2speech1> <time1> </text2speech1> </switch1flipped> </code>
# <start_comp> <player> string0 </player> <switch> switch1 </switch> <video_player> string1 </video_player> <player> string2 </player> <textbox> <text2speech> <end_comp> <code> <switch1flipped> <player1> <start> </player1> </switch1flipped> </code>
# <start_comp> <player> string0 </player> <end_comp>
# <start_comp> <passwordtextbox> <button> button1 </button> <label> label1 </label> <ball> <player> string0 </player> <accelerometer> <end_comp> <code> <button1clicked> <label1> string1 </label1> </button1clicked> <accelerometer1shaken> <ball1> <radius> number0 </radius> </ball1> </accelerometer1shaken> <ball1flung> <player1> <stop> </player1> </ball1flung> </code>
# <start_comp> <text2speech> <switch> switch1 </switch> <player> string0 </player> <label> label1 </label> <textbox> <end_comp> <code> <switch1flipped> <text2speech1> <textboxtext1> </text2speech1> </switch1flipped> </code>
# <start_comp> <textbox> <textbox> <label> label1 </label> <player> string0 </player> <button> button1 </button> <timepicker> <end_comp> <code> <button1clicked> <label1> <textboxtext2> </label1> </button1clicked> </code>
# <start_comp> <ball> <accelerometer> <player> string0 </player> <switch> switch1 </switch> <end_comp> <code> <ball1flung> <player1> <stop> </player1> </ball1flung> <accelerometer1shaken> <ball1> <heading> number0 </heading> </ball1> </accelerometer1shaken> </code>
# <start_comp> <button> button1 </button> <timepicker> <text2speech> <accelerometer> <switch> string0 </switch> <player> string1 </player> <end_comp> <code> <button1clicked> <text2speech1> <time1> </text2speech1> </button1clicked> <accelerometer1shaken> <player1> <start> </player1> </accelerometer1shaken> </code>
# <start_comp> <player> string0 </player> <player> string1 </player> <label> label1 </label> <text2speech> <end_comp>
# <start_comp> <label> label1 </label> <ball> <text2speech> <player> random_player_source </player> <end_comp> <code> <ball1flung> <text2speech1> string0 </text2speech1> </ball1flung> </code>
# <start_comp> <label> string0 </label> <timepicker> <player> string1 </player> <end_comp>
# <start_comp> <accelerometer> <player> string0 </player> <switch> string1 </switch> <video_player> string2 </video_player> <end_comp> <code> <accelerometer1shaken> <player1> <start> </player1> </accelerometer1shaken> <switch1flipped> <video_player1> <start> </video_player1> </switch1flipped> </code>
# <start_comp> <button> button1 </button> <player> string0 </player> <accelerometer> <timepicker> <end_comp> <code> <button1clicked> <player1> <start> </player1> </button1clicked> </code>
# <start_comp> <ball> <textbox> <player> string0 </player> <text2speech> <label> label1 </label> <end_comp> <code> <ball1reach_edge> <player1> <stop> </player1> </ball1reach_edge> </code>
# <start_comp> <video_player> string0 </video_player> <player> string1 </player> <player> string2 </player> <end_comp>
# <start_comp> <button> button1 </button> <accelerometer> <player> random_player_source </player> <video_player> string0 </video_player> <end_comp> <code> <button1clicked> <video_player1> <stop> </video_player1> </button1clicked> <accelerometer1shaken> <player1> <start> </player1> </accelerometer1shaken> </code>
# <start_comp> <timepicker> <button> button1 </button> <button> string0 </button> <label> label1 </label> <player> string1 </player> <switch> switch1 </switch> <text2speech> <end_comp> <code> <button1clicked> <player1> <stop> </player1> </button1clicked> <button2clicked> <label1> <time1> </label1> </button2clicked> <switch1flipped> <text2speech1> string2 </text2speech1> </switch1flipped> </code>
# <start_comp> <text2speech> <timepicker> <accelerometer> <video_player> string0 </video_player> <player> string1 </player> <passwordtextbox> <button> button1 </button> <end_comp> <code> <accelerometer1shaken> <text2speech1> <time1> </text2speech1> </accelerometer1shaken> <button1clicked> <video_player1> <stop> </video_player1> </button1clicked> </code>
# <start_comp> <player> random_player_source </player> <switch> switch1 </switch> <ball> <accelerometer> <end_comp> <code> <switch1flipped> <player1> <start> </player1> </switch1flipped> <ball1reach_edge> <ball1> <speed> number0 </speed> </ball1> </ball1reach_edge> </code>
# <start_comp> <player> random_player_source </player> <switch> string0 </switch> <label> string1 </label> <passwordtextbox> <button> button1 </button> <accelerometer> <timepicker> <end_comp> <code> <switch1flipped> <player1> <start> </player1> </switch1flipped> <button1clicked> <label1> string2 </label1> </button1clicked> </code>
# <start_comp> <label> string0 </label> <text2speech> <ball> <button> string1 </button> <player> random_player_source </player> <label> label2 </label> <timepicker> <end_comp> <code> <ball1flung> <ball1> <speed> number0 </speed> </ball1> </ball1flung> <button1clicked> <text2speech1> string2 </text2speech1> </button1clicked> </code>
# <start_comp> <player> string0 </player> <switch> switch1 </switch> <timepicker> <end_comp> <code> <switch1flipped> <player1> <start> </player1> </switch1flipped> </code>
# <start_comp> <timepicker> <player> random_player_source </player> <textbox> <video_player> string0 </video_player> <passwordtextbox> <end_comp>
# <start_comp> <player> string0 </player> <end_comp>
# <start_comp> <textbox> <ball> <passwordtextbox> <button> button1 </button> <text2speech> <textbox> <player> string0 </player> <end_comp> <code> <ball1reach_edge> <player1> <stop> </player1> </ball1reach_edge> <button1clicked> <text2speech1> <textboxtext1> </text2speech1> </button1clicked> </code>
# <start_comp> <player> random_player_source </player> <textbox> <end_comp>
# <start_comp> <player> random_player_source </player> <textbox> <accelerometer> <ball> <passwordtextbox> <end_comp> <code> <accelerometer1shaken> <player1> <start> </player1> </accelerometer1shaken> <ball1reach_edge> <ball1> <radius> number0 </radius> </ball1> </ball1reach_edge> </code>
# <start_comp> <button> button1 </button> <textbox> <player> random_player_source </player> <passwordtextbox> <label> label1 </label> <ball> <label> label2 </label> <end_comp> <code> <button1clicked> <ball1> <color> <green> </color> </ball1> </button1clicked> <ball1flung> <player1> <stop> </player1> </ball1flung> </code>
# <start_comp> <timepicker> <player> string0 </player> <video_player> string1 </video_player> <switch> switch1 </switch> <accelerometer> <button> button1 </button> <end_comp> <code> <switch1flipped> <video_player1> <stop> </video_player1> </switch1flipped> <accelerometer1shaken> <player1> <stop> </player1> </accelerometer1shaken> </code>
# <start_comp> <player> string0 </player> <textbox> <switch> switch1 </switch> <accelerometer> <end_comp> <code> <switch1flipped> <player1> <start> </player1> </switch1flipped> </code>
# <start_comp> <timepicker> <text2speech> <player> string0 </player> <button> button1 </button> <end_comp> <code> <button1clicked> <player1> <start> </player1> </button1clicked> </code>
# <start_comp> <switch> switch1 </switch> <timepicker> <switch> switch2 </switch> <player> string0 </player> <accelerometer> <ball> <textbox> <end_comp> <code> <switch1flipped> <ball1> <bounce> </ball1> </switch1flipped> <switch2flipped> <player1> <start> </player1> </switch2flipped> </code>
# <start_comp> <text2speech> <switch> string0 </switch> <player> string1 </player> <passwordtextbox> <video_player> string2 </video_player> <end_comp> <code> <switch1flipped> <video_player1> <stop> </video_player1> </switch1flipped> </code>
# <start_comp> <button> string0 </button> <accelerometer> <player> string1 </player> <passwordtextbox> <textbox> <player> string2 </player> <button> string3 </button> <end_comp> <code> <button1clicked> <player1> <start> </player1> </button1clicked> <accelerometer1shaken> <player2> <start> </player2> </accelerometer1shaken> </code>
# <start_comp> <timepicker> <player> string0 </player> <button> string1 </button> <ball> <textbox> <label> label1 </label> <button> string2 </button> <end_comp> <code> <button1clicked> <player1> <start> </player1> </button1clicked> <ball1flung> <ball1> <bounce> </ball1> </ball1flung> <button2clicked> <label1> string3 </label1> </button2clicked> </code>
# <start_comp> <text2speech> <player> random_player_source </player> <accelerometer> <ball> <video_player> string0 </video_player> <end_comp> <code> <ball1flung> <text2speech1> string1 </text2speech1> </ball1flung> <accelerometer1shaken> <player1> <stop> </player1> </accelerometer1shaken> </code>
# <start_comp> <player> string0 </player> <button> button1 </button> <textbox> <button> button2 </button> <end_comp> <code> <button1clicked> <player1> <stop> </player1> </button1clicked> </code>
# <start_comp> <player> random_player_source </player> <accelerometer> <end_comp> <code> <accelerometer1shaken> <player1> <start> </player1> </accelerometer1shaken> </code>
# <start_comp> <video_player> string0 </video_player> <ball> <player> string1 </player> <button> button1 </button> <switch> switch1 </switch> <video_player> string2 </video_player> <end_comp> <code> <ball1flung> <video_player1> <stop> </video_player1> </ball1flung> <button1clicked> <ball1> <color> <red> </color> </ball1> </button1clicked> <switch1flipped> <video_player2> <start> </video_player2> </switch1flipped> </code>
# <start_comp> <player> string0 </player> <switch> switch1 </switch> <end_comp> <code> <switch1flipped> <player1> <stop> </player1> </switch1flipped> </code>
# <start_comp> <switch> switch1 </switch> <passwordtextbox> <textbox> <text2speech> <video_player> string0 </video_player> <player> string1 </player> <end_comp> <code> <switch1flipped> <video_player1> <stop> </video_player1> </switch1flipped> </code>
# <start_comp> <button> string0 </button> <player> random_player_source </player> <video_player> random_video_player_source </video_player> <textbox> <timepicker> <label> label1 </label> <end_comp> <code> <button1clicked> <label1> string1 </label1> </button1clicked> </code>
# <start_comp> <video_player> string0 </video_player> <player> string1 </player> <timepicker> <switch> switch1 </switch> <passwordtextbox> <button> button1 </button> <passwordtextbox> <end_comp> <code> <switch1flipped> <video_player1> <stop> </video_player1> </switch1flipped> <button1clicked> <player1> <stop> </player1> </button1clicked> </code>
# <start_comp> <player> string0 </player> <passwordtextbox> <end_comp>
# <start_comp> <player> string0 </player> <label> label1 </label> <end_comp>
# <start_comp> <player> random_player_source </player> <label> label1 </label> <accelerometer> <player> string0 </player> <ball> <end_comp> <code> <accelerometer1shaken> <label1> string1 </label1> </accelerometer1shaken> <ball1flung> <player1> <stop> </player1> </ball1flung> </code>
# <start_comp> <button> button1 </button> <switch> switch1 </switch> <timepicker> <player> random_player_source </player> <end_comp> <code> <button1clicked> <player1> <stop> </player1> </button1clicked> </code>
# <start_comp> <player> string0 </player> <button> string1 </button> <passwordtextbox> <label> label1 </label> <switch> switch1 </switch> <player> random_player_source </player> <end_comp> <code> <button1clicked> <label1> string2 </label1> </button1clicked> <switch1flipped> <player1> <start> </player1> </switch1flipped> </code>
# <start_comp> <timepicker> <textbox> <switch> string0 </switch> <timepicker> <player> string1 </player> <ball> <end_comp> <code> <switch1flipped> <player1> <start> </player1> </switch1flipped> <ball1reach_edge> <ball1> <motion> </ball1> </ball1reach_edge> </code>
# <start_comp> <accelerometer> <player> string0 </player> <end_comp> <code> <accelerometer1shaken> <player1> <start> </player1> </accelerometer1shaken> </code>
# <start_comp> <player> string0 </player> <end_comp>
# <start_comp> <text2speech> <ball> <player> random_player_source </player> <button> string0 </button> <label> string1 </label> <button> string2 </button> <end_comp> <code> <ball1flung> <ball1> <heading> number0 </heading> </ball1> </ball1flung> <button1clicked> <text2speech1> string3 </text2speech1> </button1clicked> <button2clicked> <label1> string4 </label1> </button2clicked> </code>
# <start_comp> <timepicker> <player> string0 </player> <switch> switch1 </switch> <passwordtextbox> <button> button1 </button> <passwordtextbox> <video_player> string1 </video_player> <end_comp> <code> <switch1flipped> <player1> <start> </player1> </switch1flipped> <button1clicked> <video_player1> <stop> </video_player1> </button1clicked> </code>
# <start_comp> <player> string0 </player> <ball> <end_comp> <code> <ball1reach_edge> <player1> <start> </player1> </ball1reach_edge> </code>
# <start_comp> <timepicker> <switch> switch1 </switch> <player> random_player_source </player> <label> string0 </label> <end_comp> <code> <switch1flipped> <player1> <stop> </player1> </switch1flipped> </code>
# <start_comp> <label> string0 </label> <button> button1 </button> <player> random_player_source </player> <ball> <end_comp> <code> <button1clicked> <label1> string1 </label1> </button1clicked> <ball1reach_edge> <ball1> <motion> </ball1> </ball1reach_edge> </code>
# <start_comp> <timepicker> <player> random_player_source </player> <switch> switch1 </switch> <label> label1 </label> <end_comp> <code> <switch1flipped> <player1> <start> </player1> </switch1flipped> </code>
# <start_comp> <player> string0 </player> <textbox> <label> label1 </label> <passwordtextbox> <text2speech> <video_player> string1 </video_player> <ball> <end_comp> <code> <ball1flung> <player1> <start> </player1> </ball1flung> </code>
# <start_comp> <passwordtextbox> <switch> string0 </switch> <accelerometer> <button> string1 </button> <ball> <player> string2 </player> <end_comp> <code> <switch1flipped> <ball1> <speed> number0 </speed> </ball1> </switch1flipped> <accelerometer1shaken> <player1> <start> </player1> </accelerometer1shaken> </code>
# <start_comp> <timepicker> <button> button1 </button> <textbox> <player> random_player_source </player> <passwordtextbox> <text2speech> <end_comp> <code> <button1clicked> <player1> <stop> </player1> </button1clicked> </code>
# <start_comp> <player> random_player_source </player> <video_player> string0 </video_player> <video_player> string1 </video_player> <button> button1 </button> <switch> string2 </switch> <textbox> <end_comp> <code> <button1clicked> <video_player1> <stop> </video_player1> </button1clicked> <switch1flipped> <player1> <stop> </player1> </switch1flipped> </code>

# %%
import pandas as pd
df = pd.DataFrame({'NL':nl_list, 'SAR': sar_list})

# %%
df
# Out:
#                                                       NL                                                SAR
# 0                       software containing a text box .                  <start_comp> <textbox> <end_comp>
# 1      create mobile application consisting of a circ...  <start_comp> <ball> <end_comp> <code> <ball1fl...
# 2      make mobile app consisting a password box , a ...  <start_comp> <passwordtextbox> <textbox> <time...
# 3      an application that has a video player with so...  <start_comp> <video_player> string0 </video_pl...
# 4      create mobile application consisting an accele...  <start_comp> <accelerometer> <player> random_p...
# ...                                                  ...                                                ...
# 54995                   application containing a label .    <start_comp> <label> label1 </label> <end_comp>
# 54996  create an application with an audio with a ran...  <start_comp> <player> random_player_source </p...
# 54997  mobile application with a switch named string0...  <start_comp> <switch> string0 </switch> <textb...
# 54998  give me a mobile application that has a text b...     <start_comp> <textbox> <timepicker> <end_comp>
# 54999  give me application consisting of a video with...  <start_comp> <video_player> string0 </video_pl...
#
# [55000 rows x 2 columns]

# %%
df = df.drop_duplicates()
df
# Out:
#                                                       NL                                                SAR
# 0                       software containing a text box .                  <start_comp> <textbox> <end_comp>
# 1      create mobile application consisting of a circ...  <start_comp> <ball> <end_comp> <code> <ball1fl...
# 2      make mobile app consisting a password box , a ...  <start_comp> <passwordtextbox> <textbox> <time...
# 3      an application that has a video player with so...  <start_comp> <video_player> string0 </video_pl...
# 4      create mobile application consisting an accele...  <start_comp> <accelerometer> <player> random_p...
# ...                                                  ...                                                ...
# 54993  software consisting an accelerometer , a label...  <start_comp> <accelerometer> <label> label1 </...
# 54996  create an application with an audio with a ran...  <start_comp> <player> random_player_source </p...
# 54997  mobile application with a switch named string0...  <start_comp> <switch> string0 </switch> <textb...
# 54998  give me a mobile application that has a text b...     <start_comp> <textbox> <timepicker> <end_comp>
# 54999  give me application consisting of a video with...  <start_comp> <video_player> string0 </video_pl...
#
# [51825 rows x 2 columns]

# %%
df = df[:50000]

# %%
df.to_csv("nl_sar.csv", index=False)

# %%
train_frac = 0.8
valid_frac = 0.1

train = df[:int(len(df)*train_frac)]
valid = df[int(len(df)*train_frac): int(len(df)*(train_frac+valid_frac))]
test = df[int(len(df)*(train_frac+valid_frac)): ]

train.to_csv("nl_sar_train.csv", index=False)
test.to_csv("nl_sar_test.csv", index=False)
valid.to_csv("nl_sar_valid.csv", index=False)

len(train), len(valid), len(test)
# Out:
# (40000, 5000, 5000)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !cp nl_sar_* /content/drive/MyDrive/Model_Testing/

# %% [markdown]
# ## Training Data

# %%
data = {
    "train": train,
    "test": test,
    "valid": valid
}

# %%
# !mkdir -p data

# %%
for key in data.keys():
  fp_input = open("data/src_{}.txt".format(key), 'w+')
  fp_input.write('\n'.join(list(data[key]['NL'].values)))
  fp_input.c
  +lose

  fp_input = open("data/tgt_{}.txt".format(key), 'w+')
  fp_input.write('\n'.join(list(data[key]['SAR'].values)))
  fp_input.close

# %% [markdown]
# ## Synthetic data anlaytics

# %%
nl_len = []
sar_len = []
for nl in nl_list:
  nl_len.append(len(nl.split()))

for sar in sar_list:
  sar_len.append(len(sar.split()))

# %%
sum(nl_len)/len(nl_len)
# Out:
# 30.73736

# %%
sum(sar_len)/len(sar_len)
# Out:
# 16.04008

# %%
max(nl_len), min(nl_len)
# Out:
# (82, 5)

# %%
max(sar_len), min(sar_len)
# Out:
# (45, 3)
